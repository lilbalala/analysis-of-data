# %%
import pandas as pd

# %% [markdown]
# # 创建Series

# %%
s = pd.Series(['banana',42])
s
# Out:
# 0    banana
# 1        42
# dtype: object

# %%
s1 = pd.Series(['lilbalala','lishuaihui'],index = ['AKA','Name'])
s1
# Out:
# AKA      lilbalala
# Name    lishuaihui
# dtype: object

# %% [markdown]
# # 创建DataFrame

# %%
name_list = pd.DataFrame(data = {'姓名':['张三','李四','王五'],'性别':['男','女','男'],'成绩':[96,35,74]}, columns = ['姓名','性别','成绩'])
name_list
# Out:
#    姓名 性别  成绩
# 0  张三  男  96
# 1  李四  女  35
# 2  王五  男  74

# %% [markdown]
# # Series常用操作

# %%
data = pd.read_csv(r'E:\数据分析\4.26第一天课程资料\数据\nobel_prizes.csv',index_col = 'id')
data
# Out:
#      year    category overallMotivation         firstname      surname  \
# id
# 941  2017     physics               NaN            Rainer        Weiss
# 942  2017     physics               NaN          Barry C.       Barish
# 943  2017     physics               NaN            Kip S.       Thorne
# 944  2017   chemistry               NaN           Jacques     Dubochet
# 945  2017   chemistry               NaN           Joachim        Frank
# ..    ...         ...               ...               ...          ...
# 160  1901   chemistry               NaN  Jacobus Henricus  van 't Hoff
# 293  1901    medicine               NaN        Emil Adolf  von Behring
# 569  1901  literature               NaN             Sully    Prudhomme
# 462  1901       peace               NaN        Jean Henry       Dunant
# 463  1901       peace               NaN          Frédéric        Passy
#
#                                             motivation  share
# id
# ...

# %% [markdown]
# ## Series常用属性

# %%
data.loc[293]
# Out:
# year                                                              1901
# category                                                      medicine
# overallMotivation                                                  NaN
# firstname                                                   Emil Adolf
# surname                                                    von Behring
# motivation           "for his work on serum therapy, especially its...
# share                                                                1
# Name: 293, dtype: object

# %%
data.iloc[2]
# Out:
# year                                                              2017
# category                                                       physics
# overallMotivation                                                  NaN
# firstname                                                       Kip S.
# surname                                                         Thorne
# motivation           "for decisive contributions to the LIGO detect...
# share                                                                4
# Name: 943, dtype: object

# %%
share = data['share']
share
# Out:
# id
# 941    2
# 942    4
# 943    4
# 944    3
# 945    3
#       ..
# 160    1
# 293    1
# 569    1
# 462    2
# 463    2
# Name: share, Length: 923, dtype: int64

# %%
share.max()
# Out:
# 4

# %%
share.mean()
# Out:
# 1.982665222101842

# %%
share.value_counts()
# Out:
# share
# 1    347
# 2    307
# 3    207
# 4     62
# Name: count, dtype: int64

# %%
movie = pd.read_csv(r'E:\数据分析\4.26第一天课程资料\数据\movie.csv')
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## Series的常用方法

# %%
director = movie['director_name']

# %%
director.value_counts()
# Out:
# director_name
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: count, Length: 2397, dtype: int64

# %%
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
movie['duration'].describe()
#%25
# Out:
# count    4901.000000
# mean      107.090798
# std        25.286015
# min         7.000000
# 25%        93.000000
# 50%       103.000000
# 75%       118.000000
# max       511.000000
# Name: duration, dtype: float64

# %%
scientists = pd.read_csv(r'E:\数据分析\4.26第一天课程资料\数据\scientists.csv')
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
gt_mean = scientists['Age']>scientists['Age'].mean()
gt_mean
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %% [markdown]
# ## 使用布尔索引进行数据筛选

# %%
scientists['Name'][gt_mean]
# Out:
# 1          William Gosset
# 2    Florence Nightingale
# 3             Marie Curie
# 7            Johann Gauss
# Name: Name, dtype: object

# %%
scientists.max()
# Out:
# Name          William Gosset
# Born              1920-07-25
# Died              1964-04-14
# Age                       90
# Occupation      Statistician
# dtype: object

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ## 运算

# %%
add = movie+movie
add
# Out:
#            color                       director_name  num_critic_for_reviews  \
# 0     ColorColor          James CameronJames Cameron                  1446.0
# 1     ColorColor        Gore VerbinskiGore Verbinski                   604.0
# 2     ColorColor                Sam MendesSam Mendes                  1204.0
# 3     ColorColor  Christopher NolanChristopher Nolan                  1626.0
# 4            NaN              Doug WalkerDoug Walker                     NaN
# ...          ...                                 ...                     ...
# 4911  ColorColor              Scott SmithScott Smith                     2.0
# 4912  ColorColor                                 NaN                    86.0
# 4913  ColorColor    Benjamin RoberdsBenjamin Roberds                    26.0
# 4914  ColorColor              Daniel HsiaDaniel Hsia                    28.0
# 4915  ColorColor                    Jon GunnJon Gunn                    86.0
#
# ...

# %% [markdown]
# # DataFrame修改行列索引

# %% [markdown]
# ## 给行索引命名

# %%
movie = pd.read_csv(r'E:\develop\数据\movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.reset_index()
# Out:
#       index  color      director_name  num_critic_for_reviews  duration  \
# 0         0  Color      James Cameron                   723.0     178.0
# 1         1  Color     Gore Verbinski                   302.0     169.0
# 2         2  Color         Sam Mendes                   602.0     148.0
# 3         3  Color  Christopher Nolan                   813.0     164.0
# 4         4    NaN        Doug Walker                     NaN       NaN
# ...     ...    ...                ...                     ...       ...
# 4911   4911  Color        Scott Smith                     1.0      87.0
# 4912   4912  Color                NaN                    43.0      43.0
# 4913   4913  Color   Benjamin Roberds                    13.0      76.0
# 4914   4914  Color        Daniel Hsia                    14.0     100.0
# 4915   4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# ...

# %%
movie = movie.reset_index()
movie
# Out:
#       duration  color      director_name  num_critic_for_reviews  \
# 0        178.0  Color      James Cameron                   723.0
# 1        169.0  Color     Gore Verbinski                   302.0
# 2        148.0  Color         Sam Mendes                   602.0
# 3        164.0  Color  Christopher Nolan                   813.0
# 4          NaN    NaN        Doug Walker                     NaN
# ...        ...    ...                ...                     ...
# 4911      87.0  Color        Scott Smith                     1.0
# 4912      43.0  Color                NaN                    43.0
# 4913      76.0  Color   Benjamin Roberds                    13.0
# 4914     100.0  Color        Daniel Hsia                    14.0
# 4915      90.0  Color           Jon Gunn                    43.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## 修改列名

# %%
movie.columns
# Out:
# Index(['duration', 'color', 'director_name', 'num_critic_for_reviews',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
new_column = ['时长', 'color', '导演名字', 'num_critic_for_reviews',
       'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
       'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
       'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
       'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
       'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
       'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
       'imdb_score', 'aspect_ratio', 'movie_facebook_likes']

# %%
movie.columns = new_column
movie
# Out:
#          时长  color               导演名字  num_critic_for_reviews  \
# 0     178.0  Color      James Cameron                   723.0
# 1     169.0  Color     Gore Verbinski                   302.0
# 2     148.0  Color         Sam Mendes                   602.0
# 3     164.0  Color  Christopher Nolan                   813.0
# 4       NaN    NaN        Doug Walker                     NaN
# ...     ...    ...                ...                     ...
# 4911   87.0  Color        Scott Smith                     1.0
# 4912   43.0  Color                NaN                    43.0
# 4913   76.0  Color   Benjamin Roberds                    13.0
# 4914  100.0  Color        Daniel Hsia                    14.0
# 4915   90.0  Color           Jon Gunn                    43.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# ...

# %% [markdown]
# ## 使用rename方式修改

# %%
movie.head()
# Out:
#       时长  color               导演名字  num_critic_for_reviews  \
# 0  178.0  Color      James Cameron                   723.0
# 1  169.0  Color     Gore Verbinski                   302.0
# 2  148.0  Color         Sam Mendes                   602.0
# 3  164.0  Color  Christopher Nolan                   813.0
# 4    NaN    NaN        Doug Walker                     NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.rename(index={0:'第一',1:'第二'},columns={'color':'色彩'},inplace = True)

# %%
movie.head()
# Out:
#        时长     色彩               导演名字  num_critic_for_reviews  \
# 第一  178.0  Color      James Cameron                   723.0
# 第二  169.0  Color     Gore Verbinski                   302.0
# 2   148.0  Color         Sam Mendes                   602.0
# 3   164.0  Color  Christopher Nolan                   813.0
# 4     NaN    NaN        Doug Walker                     NaN
#
#     director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 第一                      0.0                   855.0  Joel David Moore
# 第二                    563.0                  1000.0     Orlando Bloom
# 2                       0.0                   161.0      Rory Kinnear
# 3                   22000.0                 23000.0    Christian Bale
# 4                     131.0                     NaN        Rob Walker
#
#     actor_1_facebook_likes        gross                           genres  ...  \
# 第一                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...
